# %% [markdown]
# <a href="https://colab.research.google.com/github/rawa-elargab/Amazon-Discount-EDA/blob/main/Amazon_Discounts_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Inspiration and objective
# The objective is to find the best products at good price with discounts

# %%
import numpy as np 
import pandas as pd 
import plotly.express as px
import os

# %%
path = "/content/Amazon-Products.csv"
df = pd.read_csv(path, low_memory=False)
df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1           1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2           2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3           3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4           4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#   main_category      sub_category  \
# 0    appliances  Air Conditioners
# 1    appliances  Air Conditioners
# 2    appliances  Air Conditioners
# 3    appliances  Air Conditioners
# 4    appliances  Air Conditioners
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link ratings no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...     4.2         2,255
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.2         2,948
# 2  https://www.amazon.in/LG-Inverter-Convertible-...     4.2         1,206
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...     4.0            69
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...     4.1           630
#
#   discount_price actual_price
# 0        ₹32,999      ₹58,990
# 1        ₹46,490      ₹75,990
# 2        ₹34,490      ₹61,990
# 3        ₹37,990      ₹68,990
# 4        ₹34,490      ₹67,790

# %%
# Knowing the number of rows and columns
df.shape
# Out:
# (37165, 10)

# %%
# Checking the missing values
df.isnull().sum()
# Out:
# Unnamed: 0           0
# name                 0
# main_category        1
# sub_category         1
# image                1
# link                 1
# ratings           4675
# no_of_ratings     4675
# discount_price    2757
# actual_price       629
# dtype: int64

# %%
# Droping the columns with 70% or more missing data
perc = 70.0 
min_count =  int(((100 - perc)/100) * df.shape[1] + 1)
mod_df = df.dropna(axis = 1, thresh = min_count)

# %%
# Number of columns are reduced significantly from 895 to 14
mod_df.shape
# Out:
# (37165, 10)

# %%
# Checking the column name
mod_df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'main_category', 'sub_category', 'image', 'link',
#        'ratings', 'no_of_ratings', 'discount_price', 'actual_price'],
#       dtype='object')

# %%
# Checking the data type, missing values in remaining columns
mod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37165 entries, 0 to 37164
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      37165 non-null  int64
#  1   name            37165 non-null  object
#  2   main_category   37164 non-null  object
#  3   sub_category    37164 non-null  object
#  4   image           37164 non-null  object
#  5   link            37164 non-null  object
#  6   ratings         32490 non-null  object
#  7   no_of_ratings   32490 non-null  object
#  8   discount_price  34408 non-null  object
#  9   actual_price    36536 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 2.8+ MB

# %% [markdown]
# # Clean numeric columns and set data types
# The columns actual_price, discount_price, no_of_ratings and ratings have wrong datatype.
# The datatype given is object but we want them to be int or float. Let us correct it.<br>
# The column amazon_category_and_sub_category has multiple values. In order to clean the data we will seperate them to individual columns.<br>

# %%
# Removing the ₹ sign
mod_df["discount_price"] = mod_df["discount_price"].str.split(" ", expand = True).get(0).str.split("₹", expand = True).get(1)
mod_df["actual_price"] = mod_df["actual_price"].str.split(" ", expand = True).get(0).str.split("₹", expand = True).get(1)

# %%
# Change commas to dots and change the type to float
mod_df['discount_price'] = mod_df["discount_price"].str.replace(',', '').astype(float)
mod_df["actual_price"] = mod_df["actual_price"].str.replace(',', '').astype(float)

# %% [markdown]
# There are values in the 'ratings' column that cannot be represented as a number. We replace them with '0.0'.

# %%
# Modify ratings values
mod_df['ratings'].unique()
# Out:
# array(['4.2', '4.0', '4.1', '4.3', '3.9', '3.8', '3.5', nan, '4.6', '3.3',
#        '3.4', '3.7', '2.9', '5.0', '4.4', '3.6', '2.7', '4.5', '3.0',
#        '3.1', '3.2', '4.8', '4.7', '2.5', '1.0', '2.6', '2.8', '2.3',
#        '1.7', 'Get', '1.8', '2.4', '4.9', '2.2', '1.6', '1.9', '2.0',
#        '1.4', '2.1', 'FREE', '1.2', '1.3', '1.5'], dtype=object)

# %%
# Extract the digits and change the type to float
mod_df['ratings'] = mod_df['ratings'].replace(['Get','FREE','₹68.99', '₹65','₹70', '₹100', '₹99', '₹2.99'], '0.0')
mod_df['ratings'] = mod_df["ratings"].astype(float)
mod_df['ratings'].unique()
# Out:
# array([4.2, 4. , 4.1, 4.3, 3.9, 3.8, 3.5, nan, 4.6, 3.3, 3.4, 3.7, 2.9,
#        5. , 4.4, 3.6, 2.7, 4.5, 3. , 3.1, 3.2, 4.8, 4.7, 2.5, 1. , 2.6,
#        2.8, 2.3, 1.7, 0. , 1.8, 2.4, 4.9, 2.2, 1.6, 1.9, 2. , 1.4, 2.1,
#        1.2, 1.3, 1.5])

# %% [markdown]
# #  Preprocess Rating column
# The 'no_of_ratings' column is converted to the float type in two steps: first, a new boolean column is formed, where the True value corresponds to the numeric value in the original column. Then the values ​​in the 'no_of_ratings' column are recalculated for values ​​matching the True of the 'correct_no_of_ratings' column

# %%
# Add column 'correct_no_of_ratings' which value is 'True' if 'no_of_ratings' begins from digit 
mod_df['no_of_ratings'] = mod_df['no_of_ratings'].astype(str)
mod_df['correct_no_of_ratings'] = pd.Series([mod_df['no_of_ratings'][x][0].isdigit() for x in range(len(mod_df['no_of_ratings']))])
# Drop columns with incorrect 'no_of_ratings'
mod_df = mod_df[mod_df['correct_no_of_ratings'] == True]
mod_df['correct_no_of_ratings'].value_counts()
# Out:
# True    32195
# Name: correct_no_of_ratings, dtype: int64

# %%
# Change the type to float
mod_df["no_of_ratings"] = mod_df["no_of_ratings"].str.replace(',', '').astype(float)
# Out:
# <ipython-input-14-ef8eca6b37f0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mod_df["no_of_ratings"] = mod_df["no_of_ratings"].str.replace(',', '').astype(float)

# %%
# Dataframe after first phase of cleaning
mod_df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1           1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2           2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3           3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4           4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#   main_category      sub_category  \
# 0    appliances  Air Conditioners
# 1    appliances  Air Conditioners
# 2    appliances  Air Conditioners
# 3    appliances  Air Conditioners
# 4    appliances  Air Conditioners
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2         2255.0
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2         2948.0
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2         1206.0
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.0           69.0
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...      4.1          630.0
#
#    discount_price  actual_price  correct_no_of_ratings
# 0         32999.0       58990.0                   True
# 1         46490.0       75990.0                   True
# 2         34490.0       61990.0                   True
# 3         37990.0       68990.0                   True
# 4         34490.0       67790.0                   True

# %%
mod_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32195 entries, 0 to 37163
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             32195 non-null  int64
#  1   name                   32195 non-null  object
#  2   main_category          32195 non-null  object
#  3   sub_category           32195 non-null  object
#  4   image                  32195 non-null  object
#  5   link                   32195 non-null  object
#  6   ratings                32195 non-null  float64
#  7   no_of_ratings          32195 non-null  float64
#  8   discount_price         30138 non-null  float64
#  9   actual_price           31886 non-null  float64
#  10  correct_no_of_ratings  32195 non-null  bool
# dtypes: bool(1), float64(4), int64(1), object(5)
# memory usage: 2.7+ MB

# %%
# Plot the total missing values
x = mod_df.isnull().sum()

fig = px.bar(x, orientation = "h",  text_auto='.2s',
            color_discrete_sequence= ["#ff6b00"] * len(x))
fig.update_layout(
    title="<b>Missing Value Count</b>",
    xaxis_title="Total missing values",
    yaxis_title="Column Names",
    plot_bgcolor = "#ECECEC",
    showlegend=False
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a4eb99b2-8d94-47ec-85c9-e9692b87514d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4eb99b2-8d94-47ec-85c9-e9692b87514d")) {                    Plotly.newPlot(                        "a4eb99b2-8d94-47ec-85c9-e9692b87514d",                        [{"alignmentgroup":"True","hovertemplate":"variable=0<br>value=%{x}<br>index=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#ff6b00","pattern":{"shape":""}},"name":"0","offsetgroup":"0","orientation":"h","showlegend":true,"textposition":"auto","texttemplate":"%{x:.2s}","x":[0,0,0,0,0,0,0,0,2057,309,0],"xaxis":"x","y":["Unnamed: 0","name","main_category","sub_category","image","link","ratings","no_of_ratings","discount_price","actual_price","correct_no_of_ratings"],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10 ...

# %% [markdown]
# # EDA

# %% [markdown]
# Now let us imagine we are browsing the Amazon website. What are the things that you see when you click on a product. For me the priority order is as follows:
# 1. Price
# 2. Rating
# 3. Manufacturer
# 4. Description
# 5. Customer reviews<br>
# Let us see analyze the given dataframe on following points.

# %%
# Let us check and create a dataframe of missing ratings
missing_no_of_ratings = mod_df[mod_df['actual_price'].isnull()]

missing_no_of_ratings.head(2)
# Out:
#      Unnamed: 0                                               name  \
# 76           76  LG 1.5 Ton 3 Star Hot & Cold DUAL Inverter Spl...
# 100         100  Hitachi 1.5 Ton 5 Star Inverter Split AC (Copp...
#
#     main_category      sub_category  \
# 76     appliances  Air Conditioners
# 100    appliances  Air Conditioners
#
#                                                  image  \
# 76   https://m.media-amazon.com/images/I/51hbo8yQ1E...
# 100  https://m.media-amazon.com/images/I/41AY1pk5oR...
#
#                                                   link  ratings  \
# 76   https://www.amazon.in/LG-Inverter-Convertible-...      4.0
# 100  https://www.amazon.in/Hitachi-Inverter-Copper-...      3.8
#
#      no_of_ratings  discount_price  actual_price  correct_no_of_ratings
# 76           265.0             NaN           NaN                   True
# 100          748.0             NaN           NaN                   True

# %%
# Since our further analysis is based on the price column so let us drop it.
df = mod_df.dropna(subset=['actual_price','discount_price'])
df.head()
# Out:
#    Unnamed: 0                                               name  \
# 0           0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...
# 1           1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...
# 2           2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...
# 3           3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...
# 4           4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...
#
#   main_category      sub_category  \
# 0    appliances  Air Conditioners
# 1    appliances  Air Conditioners
# 2    appliances  Air Conditioners
# 3    appliances  Air Conditioners
# 4    appliances  Air Conditioners
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2         2255.0
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2         2948.0
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2         1206.0
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.0           69.0
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...      4.1          630.0
#
#    discount_price  actual_price  correct_no_of_ratings
# 0         32999.0       58990.0                   True
# 1         46490.0       75990.0                   True
# 2         34490.0       61990.0                   True
# 3         37990.0       68990.0                   True
# 4         34490.0       67790.0                   True

# %% [markdown]
# # Extract the manufacturer from the 'name' column
# Extract the manufacturer from the 'name' column and insert the 'manufacturer' column after the 'name' column.
# To do this, we convert the 'name' column (type 'Series') into a string, split by spaces and select the first substring. We will have some incorrect names (such as 'The', 'Van', etc.) for brands which names consists of more than one word. But for many others it is okay. And I think this is enought to obtain general understanding for our purposes.

# %%
df['manufacturer'] = df['name'].str.split(' ').str[0]
cols = df.columns.tolist()
cols
# Out:
# <ipython-input-20-b962e0f71004>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ['Unnamed: 0',
#  'name',
#  'main_category',
#  'sub_category',
#  'image',
#  'link',
#  'ratings',
#  'no_of_ratings',
#  'discount_price',
#  'actual_price',
#  'correct_no_of_ratings',
#  'manufacturer']

# %%
cols = ['name',
 'manufacturer',
 'main_category',
 'sub_category',
 'image',
 'link',
 'ratings',
 'no_of_ratings',
 'discount_price',
 'actual_price']

# %%
df = df[cols]
df.head()
# Out:
#                                                 name manufacturer  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        Lloyd
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...           LG
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...           LG
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...           LG
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...      Carrier
#
#   main_category      sub_category  \
# 0    appliances  Air Conditioners
# 1    appliances  Air Conditioners
# 2    appliances  Air Conditioners
# 3    appliances  Air Conditioners
# 4    appliances  Air Conditioners
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2         2255.0
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2         2948.0
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2         1206.0
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.0           69.0
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...      4.1          630.0
#
#    discount_price  actual_price
# 0         32999.0       58990.0
# 1         46490.0       75990.0
# 2         34490.0       61990.0
# 3         37990.0       68990.0
# 4         34490.0       67790.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30138 entries, 0 to 37163
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            30138 non-null  object
#  1   manufacturer    30138 non-null  object
#  2   main_category   30138 non-null  object
#  3   sub_category    30138 non-null  object
#  4   image           30138 non-null  object
#  5   link            30138 non-null  object
#  6   ratings         30138 non-null  float64
#  7   no_of_ratings   30138 non-null  float64
#  8   discount_price  30138 non-null  float64
#  9   actual_price    30138 non-null  float64
# dtypes: float64(4), object(6)
# memory usage: 2.5+ MB

# %%
# Make column with discount net value and discounting percent 
df['discount_value'] = df['actual_price'] - df['discount_price']
df['discounting_percent'] = 1 - df['discount_price']/df['actual_price']
# Out:
# <ipython-input-24-3d1a005e72ba>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head()
# Out:
#                                                 name manufacturer  \
# 0  Lloyd 1.5 Ton 3 Star Inverter Split Ac (5 In 1...        Lloyd
# 1  LG 1.5 Ton 5 Star AI DUAL Inverter Split AC (C...           LG
# 2  LG 1 Ton 4 Star Ai Dual Inverter Split Ac (Cop...           LG
# 3  LG 1.5 Ton 3 Star AI DUAL Inverter Split AC (C...           LG
# 4  Carrier 1.5 Ton 3 Star Inverter Split AC (Copp...      Carrier
#
#   main_category      sub_category  \
# 0    appliances  Air Conditioners
# 1    appliances  Air Conditioners
# 2    appliances  Air Conditioners
# 3    appliances  Air Conditioners
# 4    appliances  Air Conditioners
#
#                                                image  \
# 0  https://m.media-amazon.com/images/I/31UISB90sY...
# 1  https://m.media-amazon.com/images/I/51JFb7FctD...
# 2  https://m.media-amazon.com/images/I/51JFb7FctD...
# 3  https://m.media-amazon.com/images/I/51JFb7FctD...
# 4  https://m.media-amazon.com/images/I/41lrtqXPiW...
#
#                                                 link  ratings  no_of_ratings  \
# 0  https://www.amazon.in/Lloyd-Inverter-Convertib...      4.2         2255.0
# 1  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.2         2948.0
# 2  https://www.amazon.in/LG-Inverter-Convertible-...      4.2         1206.0
# 3  https://www.amazon.in/LG-Convertible-Anti-Viru...      4.0           69.0
# 4  https://www.amazon.in/Carrier-Inverter-Split-C...      4.1          630.0
#
#    discount_price  actual_price  discount_value  discounting_percent
# 0         32999.0       58990.0         25991.0             0.440600
# 1         46490.0       75990.0         29500.0             0.388209
# 2         34490.0       61990.0         27500.0             0.443620
# 3         37990.0       68990.0         31000.0             0.449340
# 4         34490.0       67790.0         33300.0             0.491223

# %%
# Let us check the manufactures according to their prices
df[["actual_price", 'manufacturer']].groupby("manufacturer").mean().round(2).sort_values(by = "actual_price",
                                                                    ascending = False)
# Out:
#                 actual_price
# manufacturer
# ROCKWELL            110489.0
# O                    85260.0
# MITSUBISHI           83000.0
# Vu                   80000.0
# Proposed_Value       71999.0
# ...                      ...
# Cavin's                 40.0
# Lay’s                   30.0
# Ching's                 25.0
# Too                     20.0
# Bingo!                  10.0
#
# [8380 rows x 1 columns]

# %%
# Detail of the maximum price row
df[df["actual_price"] == df["actual_price"].max()]
# Out:
#                                                     name manufacturer  \
# 17595  Samsung Galaxy S23 Ultra 5G (Green, 12GB, 512G...      Samsung
#
#              main_category     sub_category  \
# 17595  tv, audio & cameras  All Electronics
#
#                                                    image  \
# 17595  https://m.media-amazon.com/images/I/61VfL-aiTo...
#
#                                                     link  ratings  \
# 17595  https://www.amazon.in/Samsung-Galaxy-Ultra-Gre...      4.4
#
#        no_of_ratings  discount_price  actual_price  discount_value  \
# 17595           91.0        134999.0      161999.0         27000.0
#
#        discounting_percent
# 17595             0.166668

# %%
# Detail of the minimum price row
df[df["discount_value"] == df["discount_value"].min()]
# Out:
#                                                     name manufacturer  \
# 28279  Aristocrat Dual Edge 65cm Polycarbonate & Poly...   Aristocrat
#
#       main_category    sub_category  \
# 28279        stores  Amazon Fashion
#
#                                                    image  \
# 28279  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                     link  ratings  \
# 28279  https://www.amazon.in/Aristocrat-Polycarbonate...      4.2
#
#        no_of_ratings  discount_price  actual_price  discount_value  \
# 28279          508.0          2823.0       2823.05            0.05
#
#        discounting_percent
# 28279             0.000018

# %%
# Let us check the common manufacture
values = df["manufacturer"].value_counts().keys().tolist()[:10]
counts = df["manufacturer"].value_counts().tolist()[:10]

# %%
fig = px.bar(df, y = counts, x = values,
            color_discrete_sequence = ["#EC2781"] * len(df))


fig.update_layout(
                 plot_bgcolor = "#ECECEC",
                  yaxis_title = "Count",
                xaxis_title = "Name of Manufacturers",
                  title = "<b>Popular Manufacturers Category</b>"
                 )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="16e63df2-4396-4396-8f9c-074dbf7f17b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16e63df2-4396-4396-8f9c-074dbf7f17b8")) {                    Plotly.newPlot(                        "16e63df2-4396-4396-8f9c-074dbf7f17b8",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#EC2781","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Amazon","TheGiftKart","Samsung","boAt","Spigen","Havells","Bajaj","AmazonBasics","Kuber","LG"],"xaxis":"x","y":[447,271,255,239,203,191,178,176,170,154],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{ ...

# %% [markdown]
# # ✔️ Insight 1
# From above graph we see that the Puma is most popular. Let us check the main category for the above top 10 brands

# %%
# Creating the dataframe of top 10 manufacturer
df_list = []
for i in values:
    x = df[df["manufacturer"] == i]
    df_list.append(x)
frame = pd.concat(df_list)
frame.head(2)
# Out:
#                                                  name manufacturer  \
# 65  Amazon Basics 1 Ton, 5 Star, Wi-Fi Enabled Sma...       Amazon
# 83  Amazon Basics 1.5 Ton, 5 Star, Wi-Fi Enabled S...       Amazon
#
#    main_category      sub_category  \
# 65    appliances  Air Conditioners
# 83    appliances  Air Conditioners
#
#                                                 image  \
# 65  https://m.media-amazon.com/images/I/51s3yrWntM...
# 83  https://m.media-amazon.com/images/I/51s3yrWntM...
#
#                                                  link  ratings  no_of_ratings  \
# 65  https://www.amazon.in/AmazonBasics-1-5-Ton-Air...      3.6           88.0
# 83  https://www.amazon.in/AmazonBasics-1-5-Ton-Air...      3.4           39.0
#
#     discount_price  actual_price  discount_value  discounting_percent
# 65         28990.0       49089.0         20099.0             0.409440
# 83         34990.0       56179.0         21189.0             0.377169

# %%
# Average rating of the manufactures
frame[["manufacturer", "ratings"]].groupby("manufacturer").mean().sort_values(by = "ratings",
                                                ascending = False)
# Out:
#                ratings
# manufacturer
# TheGiftKart   4.323985
# Spigen        4.309852
# LG            4.192208
# Samsung       4.142745
# AmazonBasics  4.126705
# Havells       4.056545
# boAt          4.026360
# Amazon        3.983221
# Bajaj         3.935393
# Kuber         3.897059

# %% [markdown]
# # ✔️ Insight 2
# Even though the most popular brand is Puma but the highest rated is Amazon.<br>
# Also the manufacturer Amazon is second most favourite in the popular manufacturer category. On the other hand Puma is second in terms of average rating<br>
# Let us now check the popular main category items present.

# %%
# Different main categories present
frame["main_category"].unique()
# Out:
# array(['appliances', 'car & motorbike', 'tv, audio & cameras',
#        'sports & fitness', 'grocery & gourmet foods', 'home & kitchen',
#        'pet supplies', 'stores', "kids' fashion", 'toys & baby products',
#        'bags & luggage', 'accessories'], dtype=object)

# %%
fig = px.bar(frame, "main_category", 
             color_discrete_sequence = ["#2377a4"] * len(frame))
fig.update_layout(
                 plot_bgcolor = "#ECECEC",
                  yaxis_title = "Count",
                  xaxis_title = "Main Categories",
                  title = "<b>Count of Main Categories of Products</b>"
                 )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="317d9882-ee79-42e9-a5f1-8e9688c13503" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("317d9882-ee79-42e9-a5f1-8e9688c13503")) {                    Plotly.newPlot(                        "317d9882-ee79-42e9-a5f1-8e9688c13503",                        [{"alignmentgroup":"True","hovertemplate":"main_category=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#2377a4","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","appliances","car & motorbike","car & motorbike","car & motorbike","car & motorbike","car & motorbike","car & motorbike","car & motorbike","car & motorbike","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & cameras","tv, audio & ca ...

# %% [markdown]
# # ✔️ Insight 3
# From the graph we see that 'Man's cloothing' is the popular main category. Let us select the top 10 popular main category. We are narrowing our selction to reach the goal

# %%
# Let us select the 5 popular main categories

value_main = frame["main_category"].value_counts().keys().tolist()[:5]
count_main = frame["main_category"].value_counts().tolist()[:5]
value_main
# Out:
# ['tv, audio & cameras',
#  'appliances',
#  'home & kitchen',
#  'stores',
#  'sports & fitness']

# %% [markdown]
# Let us create a new dataframe having top 10 popular manufcturers and 5 most popular main category.

# %%
df_list = []
for i in value_main:
    x = frame[frame["main_category"] == i]
    df_list.append(x)
    #print(df)
frame = pd.concat(df_list)
frame.head(2)
# Out:
#                                                     name manufacturer  \
# 11892  Amazon Basics Magic Slate 8.5-inch LCD Writing...       Amazon
# 12034  Amazon Basics Portable Multimedia Speaker| Sui...       Amazon
#
#              main_category     sub_category  \
# 11892  tv, audio & cameras  All Electronics
# 12034  tv, audio & cameras  All Electronics
#
#                                                    image  \
# 11892  https://m.media-amazon.com/images/W/IMAGERENDE...
# 12034  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                     link  ratings  \
# 11892  https://www.amazon.in/Amazon-Basics-8-5-inch-W...      4.0
# 12034  https://www.amazon.in/Amazon-Basics-Portable-M...      3.7
#
#        no_of_ratings  discount_price  actual_price  discount_value  \
# 11892          804.0           309.0         999.0           690.0
# 12034          218.0           399.0        1299.0           900.0
#
#        discounting_percent
# 11892             0.690691
# 12034             0.692841

# %%
# Let us check the popular subcategory
import seaborn as sns
cm = sns.light_palette("green", as_cmap=True)
frame_sub = frame[["main_category", "sub_category"]].groupby("main_category").count()
frame_sub.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_d1afd_row0_col0 {
#   background-color: #56aa56;
#   color: #f1f1f1;
# }
# #T_d1afd_row1_col0 {
#   background-color: #e2efe2;
#   color: #000000;
# }
# #T_d1afd_row2_col0, #T_d1afd_row3_col0 {
#   background-color: #ebf3eb;
#   color: #000000;
# }
# #T_d1afd_row4_col0 {
#   background-color: #008000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d1afd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1afd_level0_col0" class="col_heading level0 col0" >sub_category</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >main_category</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1afd_level0_row0" class="row_heading level0 row0" >appliances</th>
#       <td id="T_d1afd_row0_col0" class="data row0 col0" >795</td>
#     </tr>
#     <tr>
#       <th id="T_d1afd_level0_row1" class="row_heading level0 row1" >home & kitchen</th>
#       <td id="T_d1afd_row1_col0" class="data row1 col0" >100</td>
#     </tr>
#     <tr>
#       <th id="T_d1afd_level0_row2" class="row_heading level0 row2" >sports & fitness</th>
#       <td id="T_d1afd_row2_col0" class="data row2 col0" >56</td>
#     </tr>
#     <tr>
#       <th id="T_d1afd_level0_row3" class="row_heading level0 row3" >stores</th>
#       <td id="T_d1afd_row3_col0" class="data row3 col0" >59</td>
#     </tr>
#     <tr>
#       <th id="T_d1afd_level0_row4" class="row_heading level0 row4" >tv, audio & cameras</th>
#       <td id="T_d1afd_row4_col0" class="data row4 col0" >1225</td>
#     </tr>
#   </tbody>
# </table>

# %%
value_sub = frame["sub_category"].value_counts().keys().tolist()[:10]
count_sub = frame["sub_category"].value_counts().tolist()[:10]

# %%
# New dataframe with selected sub_category
df_list = []
for i in value_sub:
    x = frame[frame["sub_category"] == i]
    df_list.append(x)
frame = pd.concat(df_list)
frame.head(2)
# Out:
#                                                     name manufacturer  \
# 11892  Amazon Basics Magic Slate 8.5-inch LCD Writing...       Amazon
# 12034  Amazon Basics Portable Multimedia Speaker| Sui...       Amazon
#
#              main_category     sub_category  \
# 11892  tv, audio & cameras  All Electronics
# 12034  tv, audio & cameras  All Electronics
#
#                                                    image  \
# 11892  https://m.media-amazon.com/images/W/IMAGERENDE...
# 12034  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                     link  ratings  \
# 11892  https://www.amazon.in/Amazon-Basics-8-5-inch-W...      4.0
# 12034  https://www.amazon.in/Amazon-Basics-Portable-M...      3.7
#
#        no_of_ratings  discount_price  actual_price  discount_value  \
# 11892          804.0           309.0         999.0           690.0
# 12034          218.0           399.0        1299.0           900.0
#
#        discounting_percent
# 11892             0.690691
# 12034             0.692841

# %% [markdown]
# Now we have completed the second phase of data preprocessing. After this we have achieved a dataframe with following characterstics:
# 1. No null price.
# 2. Top 10 manufacturers with respect to count
# 3. Popular top 5 main categories, 10 sub_category <br>
# Let us now check the average rating and price for this selected dataframe.

# %%
# Rating of the products
print("The average rating: ",frame["ratings"].unique())

# After processing our data we have significantly reduced the size of the dataframe.
# Also the rating are now 4 or greater.
# Let us now check new average price ### check above before processing to compare.
print("The average price: ", frame["actual_price"].mean())
# Out:
# The average rating:  [4.  3.7 4.4 3.6 3.9 4.5 4.1 4.2 3.8 3.5 4.3 4.6 3.4 3.3 3.1 3.2 4.8 5.
#  4.7 4.9 3.  1.  1.4 2.6 2.3 2.8 2.9 2.4 2.7 1.7 2.5]
# The average price:  9827.661297539149

# %%
import plotly.figure_factory as ff
x = frame["actual_price"]
hist_data = [x]
group_labels = ['actual_price']

fig = ff.create_distplot(hist_data, group_labels, show_rug = False,
                        colors=["#ffd514"])
fig.update_layout(
                 plot_bgcolor = "#ECECEC",
                  title = "<b>Price Distribution of Data</b>"
                 )

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="20e4e626-c792-4fce-819b-6fe85b58b9ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20e4e626-c792-4fce-819b-6fe85b58b9ef")) {                    Plotly.newPlot(                        "20e4e626-c792-4fce-819b-6fe85b58b9ef",                        [{"autobinx":false,"histnorm":"probability density","legendgroup":
" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3cce0073-848b-4701-8b9a-f0b72a2deefd")) {                    Plotly.newPlot(                        "3cce0073-848b-4701-8b9a-f0b72a2deefd",                        [{"alignmentgroup":"True","hovertemplate":"actual_price=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[999.0,1299.0,995.0,700.0,750.0,1099.0,499.0,695.0,999.0,500.0,750.0,1099.0,499.0,475.0,1999.0,1200.0,1999.0,2999.0,1125.0,2500.0,1000.0,845.0,2999.0,299.0,1099.0,1999.0,845.0,399.0,395.0,795.0,1999.0,2999.0,1700.0,3699.0,699.0,899.0,299.0,599.0,3500.0,499.0,600.0,299.0,600.0,1999.0,2799.0,999.0,299.0,499.0,699.0,1400.0,1490.0,6100.0,2999.0,1999.0,749.0,485.0,299.0,499.0,2100.0,916.0,445.0,1999.0,1999.0,2999.0,499.0,1300.0,499.0,999.0,299.0,1999.0,3699.0,1400.0,845.0,999.0,6099.0,499.0,1999.0,700.0,3999.0,1299.0,2999.0,1999.0,599.0,399.0,1000.0,499.0,2599.0,3000.0,499.0,1295.0,900.0,499.0,1999.0,2999.0,299.0,595.0,499.0,299.0,1000.0,299.0,599.0,499.0,795.0,1999.0,1499.0,2399.0,299.0,499.0,399.0,299.0,3000.0,899.0,299.0,699.0,600.0,999.0,4399.0,299.0,399.0,499.0,499.0,299.0,999.0,699.0,1399.0,1999.0,499.0,499.0,2999.0,299.0,499.0,299.0,119.0,299.0,499.0,499.0,499.0,399.0,299.0,499.0,299.0,1899.0,499.0,499.0,299.0,499.0,599.0,2199.0,499.0,499.0,299.0,299.0,999.0,499.0,399.0,399.0,499.0,1200.0,499.0,499.0,299.0,445.0,499.0,3999.0,299.0,3600.0,499.0,499.0,499.0,399.0,299.0,399.0,499.0,499.0,999.0,299.0,1800.0,499.0,499.0,499.0,795.0,4799.0,399.0,299.0,499.0,1499.0,499.0,299.0,299.0,399.0,449.0,1300.0,499.0,1200.0,299.0,299.0,299.0,800.0,499.0,299.0,499.0,3400.0,499.0,399.0,299.0,13500.0,999.0,499.0,499.0,1519.0,299.0,349.0,1150.0,800.0,2999.0,2499.0,499.0,1000.0,499.0,499.0,399.0,399.0,219.0,499.0,399.0,499.0,2699.0,1400.0,899.0,899.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,999.0,24999.0,24999.0,1699.0,11999.0,2699.0,11999.0,25999.0,1699.0,1899.0,22900.0,17999.0,25999.0,17999.0,15990.0,14999.0,14999.0,74999.0,499.0,13499.0,32999.0,21000.0,134 ...

# %%
# Let us find the outliers
Q1 = 1399
Q2 = 2199
Q3 = 3599
IQR = Q3 - Q1
outlier1 = (Q1 - 1.5 * IQR)
outlier2 = (Q3 + 1.5 * IQR)
print("outlier1: ", outlier1)
print("outlier2: ", outlier2)
# Out:
# outlier1:  -1901.0
# outlier2:  6899.0

# %%
outlier_price = []

for i in frame.actual_price:
    if i < outlier1 or i > outlier2:
        outlier_price.append("outlier")
    elif i > outlier1 or i < outlier2:
        outlier_price.append("normal")
    
frame["outlier_price"] = outlier_price

# %%
fig = px.pie(frame, names = frame["outlier_price"], color = frame["outlier_price"],
             color_discrete_map={'normal': '#2377a4', 'outlier': '#ffd514'})

fig.update_layout(title = "<b>Distribution of Outlier</b>")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="66f917bd-e91c-4268-805f-9c72748a9db0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("66f917bd-e91c-4268-805f-9c72748a9db0")) {                    Plotly.newPlot(                        "66f917bd-e91c-4268-805f-9c72748a9db0",                        [{"customdata":[["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["outlier"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["normal"],["no ...

# %%
# Let us see the outlier value
frame_outlier = frame.loc[frame["outlier_price"] == "outlier"].head()
frame_outlier
# Out:
#                                                     name manufacturer  \
# 20170  Amazon Basics 21.5-Inch (54.5cm) LCD 1920 x 10...       Amazon
# 11571  Samsung Galaxy M33 5G (Mystique Green, 6GB, 12...      Samsung
# 11577  Samsung Galaxy M33 5G (Emerald Brown, 6GB, 128...      Samsung
# 11611  Samsung Galaxy M04 Light Green, 4GB RAM, 64GB ...      Samsung
# 11636  Samsung Galaxy M04 Dark Blue, 4GB RAM, 64GB St...      Samsung
#
#              main_category     sub_category  \
# 20170  tv, audio & cameras  All Electronics
# 11571  tv, audio & cameras  All Electronics
# 11577  tv, audio & cameras  All Electronics
# 11611  tv, audio & cameras  All Electronics
# 11636  tv, audio & cameras  All Electronics
#
#                                                    image  \
# 20170  https://m.media-amazon.com/images/I/91Mjsd471N...
# 11571  https://m.media-amazon.com/images/I/81I3w4J6yj...
# 11577  https://m.media-amazon.com/images/I/81lnKynSaq...
# 11611  https://m.media-amazon.com/images/I/814ePfNubR...
# 11636  https://m.media-amazon.com/images/I/81t6Av5DvX...
#
#                                                     link  ratings  \
# 20170  https://www.amazon.in/AmazonBasics-21-Inch-Res...      3.9
# 11571  https://www.amazon.in/Samsung-Mystique-Storage...      4.1
# 11577  https://www.amazon.in/Samsung-Emerald-Storage-...      4.1
# 11611  https://www.amazon.in/Samsung-Galaxy-Storage-M...      4.0
# 11636  https://www.amazon.in/Samsung-Galaxy-Storage-M...      4.0
#
#        no_of_ratings  discount_price  actual_price  discount_value  \
# 20170          102.0          5939.0       13500.0          7561.0
# 11571        24863.0         15999.0       24999.0          9000.0
# 11577        24863.0         15999.0       24999.0          9000.0
# 11611         1754.0          8499.0       11999.0          3500.0
# 11636         1754.0          8499.0       11999.0          3500.0
#
#        discounting_percent outlier_price
# 20170             0.560074       outlier
# 11571             0.360014       outlier
# 11577             0.360014       outlier
# 11611             0.291691       outlier
# 11636             0.291691       outlier

# %%
print("Manufacturers with outlier price: ", frame_outlier.manufacturer.value_counts())
# Out:
# Manufacturers with outlier price:  Samsung    4
# Amazon     1
# Name: manufacturer, dtype: int64

# %%
# Top category
print("Main category with outliers: ", frame_outlier.main_category.value_counts())
# Out:
# Main category with outliers:  tv, audio & cameras    5
# Name: main_category, dtype: int64

# %%
print("Sub_category with outliers: ",frame_outlier.sub_category.value_counts())
# Out:
# Sub_category with outliers:  All Electronics    5
# Name: sub_category, dtype: int64

# %%
# Let us check the rating of the products
fig = px.violin(frame, "ratings", 
               color_discrete_sequence = ["#FFBF00"] * len(frame))
fig.update_layout(
                 plot_bgcolor = "#ECECEC",
                  xaxis_title = "Rating",
                  title = "<b>Rating Distribution of the Popular Products</b>"
                 )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="
# %%
# Let us check if there are any null review
print("Number of null values: ",frame['no_of_ratings'].isnull().sum())
# It seems that with high end products people love to leave a review
# Out:
# Number of null values:  0

# %%
frame.head(2)
# Out:
#                                                     name manufacturer  \
# 11892  Amazon Basics Magic Slate 8.5-inch LCD Writing...       Amazon
# 12034  Amazon Basics Portable Multimedia Speaker| Sui...       Amazon
#
#              main_category     sub_category  \
# 11892  tv, audio & cameras  All Electronics
# 12034  tv, audio & cameras  All Electronics
#
#                                                    image  \
# 11892  https://m.media-amazon.com/images/W/IMAGERENDE...
# 12034  https://m.media-amazon.com/images/W/IMAGERENDE...
#
#                                                     link  ratings  \
# 11892  https://www.amazon.in/Amazon-Basics-8-5-inch-W...      4.0
# 12034  https://www.amazon.in/Amazon-Basics-Portable-M...      3.7
#
#        no_of_ratings  discount_price  actual_price  discount_value  \
# 11892          804.0           309.0         999.0           690.0
# 12034          218.0           399.0        1299.0           900.0
#
#        discounting_percent outlier_price
# 11892             0.690691        normal
# 12034             0.692841        normal

# %%
frame['no_of_ratings']
# Out:
# 11892       804.0
# 12034       218.0
# 12038    437651.0
# 12173    437651.0
# 12336     36689.0
#            ...
# 25788       137.0
# 25922       250.0
# 26185     20247.0
# 35476        36.0
# 35489        35.0
# Name: no_of_ratings, Length: 2235, dtype: float64

# %%
fig = px.scatter(frame, x="discounting_percent", y="no_of_ratings", 
                 trendline="ols")
fig.update_yaxes(range=[0, 1000])
fig.update_layout(title = "<b>Relationship between the number of reviews and discount percent</b>",
                 plot_bgcolor = "#ECECEC",
                 yaxis_title = "Number of reviews",
                 xaxis_title = "Discount percent")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="55365f2c-1e9f-4884-ac8d-566591682cec" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("55365f2c-1e9f-4884-ac8d-566591682cec")) {                    Plotly.newPlot(                        "55365f2c-1e9f-4884-ac8d-566591682cec",                        [{"hovertemplate":"discounting_percent=%{x}<br>no_of_ratings=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","showlegend":false,"x":[0.6906906906906907,0.6928406466512702,0.6190954773869346,0.6157142857142857,0.5746666666666667,0.6551410373066424,0.7214428857715431,0.6273381294964029,0.5205205205205206,0.602,0.708,0.6733393994540491,0.7214428857715431,0.4336842105263158,0.6453226613306653,0.8091666666666667,0.40020010005002504,0.8102700900300099,0.6631111111111111,0.6204000000000001,0.6910000000000001,0.527810650887574,0.6535511837279093,0.7692307692307692,0.6642402183803457,0.20010005002501252,0.8118343195266272,0.6516290726817042,0.3949367088607595,0.6867924528301887,0.5252626313156579,0.7002334111370456,0.53,0.5866450391997837,0.5450643776824035,0.67853170189099,0.6020066889632107,0.8514190317195326,0.5288571428571429,0.6613226452905812,0.635,0.5351170568561873,0.635,0.6453226613306653,0.6430868167202572,0.2702702702702703,0.5351170568561873,0.7214428857715431,0.3004291845493562,0.7507142857142857,0.7456375838926175,0.508360655737705,0.7002334111370456,0.6703351675837919,0.6809078771695594,0.4041237113402062,0.5351170568561873,0.7214428857715431,0.5242857142857142,0.4552401746724891,0.10337078651685394,0.5702851425712856,0.5002501250625313,0.4534844948316106,0.6613226452905812,0.6469230769230769,0.7214428857715431,